# %%
from tld import get_tld 
import csv 
from urllib.parse import urlparse

domains_names = {}
count = 0

# opening the CSV file 
with open('final-URLs.csv', mode ='r')as file: 
    
  # reading the CSV file 
  csvFile = csv.reader(file) 
  
  # displaying the contents of the CSV file 
  for lines in csvFile:  
    res = get_tld(lines[0], as_object=True) #Get the root as an object 
    print (res.fld) #res.fld to extract the domain 
    domains_names.setdefault(res.fld, 0)

    domains_names[res.fld] += 1
# Out:
# newsteller.org
# washingtonpost.com
# feedburner.com
# mediasuarakyat.ga
# feedblitz.com
# rt.com
# theduran.com
# extrasensoryprecepts.blogspot.com
# sputniknews.com
# thetruthseeker.co.uk
# therealnews.com
# independent.co.uk
# veteranstoday.com
# thedailysheeple.com
# newsdeeply.com
# sott.net
# thesyriacampaign.org
# ems1.com
# seosem.es
# bbc.co.uk
# 21stcenturywire.com
# aljazeera.com
# yahoo.com
# gridirongarb.blogspot.com
# washingtonsblog.com
# 21stcenturywire.com
# sputniknews.com
# wrongkindofgreen.org
# rt.com
# steemit.com
# buzzfeed.com
# dailystar.com.lb
# independent.co.uk
# go.com
# mintpressnews.com
# mintpressnews.com
# nancysix.org
# spotify.com
# wikipedia.org
# blauerbote.com
# liveleak.com
# alligatorarmy.com
# kiblat.net
# wordpress.com
# wrongkindofgreen.org
# newslocker.com
# worldtruth.tv
# w3livenews.com
# informazione.it
# nationalist.ie
# bouchardgraccer.blogspot.com
# campaign-archive2.com
# cnn.com
# netflix.com
# ronpaulinstitute.org
# occasion-to-be.com
# theguardian.com
# earthlink.com
# wikipedia.org
# sputniknews.com
# nationalist.ie
# wrongkindofgreen.org
# clasos.com.mx
# rt.com
# fundmycause.net
# wordpress.com
# lzomedia.com
# wordpress.com
# sharjah24.ae
# blacklistednews.com
# middleeasteye.net
# alarabiya.net
# cbsnews.com
# altnews.top
# wordpress.com
# telegraph.co.uk
# aa.com.tr
# russia-insider.com
# google.com
# therussophile.org
# theonlycolors.com
# mirror.co.uk
# irishtimes.com
# sinkers.org
# linkedin.com
# thefreethoughtproject.com
# worldaffairs.blog
# kiblat.net
# farsnews.com
# feedburner.com
# rightrelevance.com
# quiboat.com
# tumblr.com
# 1clickdaily.com
# truepatriot.net
# informationclearinghouse.info
# timesofnews.com
# feedburner.com
# noesis2017.com
# 21stcenturywire.com
# theamericanconservative.com
# podomatic.com
# dailymail.co.uk
# google.com
# adf.ly
# ipsnews.net
# salon.com
# foxnews.com
# rt.com
# independent.co.uk
# 21stcenturywire.com
# 1newsnet.com
# telesurtv.net
# lasvegasnvblog.com
# deazijnpisser.blogspot.com
# yahoo.com
# wordpress.com
# theintercept.com
# google.com
# hnvnews.com
# 1clickdaily.com
# dailymail.co.uk
# mintpressnews.com
# getpocket.com
# 1newsnet.com
# blacklistednews.com
# nbcnews.com

# %%
# !pipenv install tweepy
# Out:
# Installing tweepy…
# Adding tweepy to Pipfile's [packages]…
# ✔ Installation Succeeded
# Installing dependencies from Pipfile.lock (e28e84)…
#   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 0/0 — 00:00:00

# %%
import tweepy
#from tweepy.auth import OAuthHandler
import webbrowser

consumer_key = "7ZOCRSoDj7s98J1rIoKNEfaC8"
consumer_secret_key = "VpuPG2kLwF9b63ryupu3lLrcS01Wi3IDfsZLX7xNdv0HVwLvzC"
callback_uri ='oob'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret_key, callback_uri)
redirect_url = auth.get_authorization_url()

webbrowser.open(redirect_url)

user_pin_input = input("whats is the pin? ")

auth.get_access_token(user_pin_input)

api = tweepy.API(auth, wait_on_rate_limit=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-6b8ebef0d961> in <module>
#       7 callback_uri ='oob'
#       8
# ----> 9 auth = tweepy.OAuthHandler(consumer_key, consumer_secret_key, callback_uri)
#      10 redirect_url = auth.get_authorization_url()
#      11
#
# AttributeError: module 'tweepy' has no attribute 'OAuthHandler'

# %%
for name, num in domains_names.items():
    print(name)
# Out:
# newsteller.org
# washingtonpost.com
# feedburner.com
# mediasuarakyat.ga
# feedblitz.com
# rt.com
# theduran.com
# extrasensoryprecepts.blogspot.com
# sputniknews.com
# thetruthseeker.co.uk
# therealnews.com
# independent.co.uk
# veteranstoday.com
# thedailysheeple.com
# newsdeeply.com
# sott.net
# thesyriacampaign.org
# ems1.com
# seosem.es
# bbc.co.uk
# 21stcenturywire.com
# aljazeera.com
# yahoo.com
# gridirongarb.blogspot.com
# washingtonsblog.com
# wrongkindofgreen.org
# steemit.com
# buzzfeed.com
# dailystar.com.lb
# go.com
# mintpressnews.com
# nancysix.org
# spotify.com
# wikipedia.org
# blauerbote.com
# liveleak.com
# alligatorarmy.com
# kiblat.net
# wordpress.com
# newslocker.com
# worldtruth.tv
# w3livenews.com
# informazione.it
# nationalist.ie
# bouchardgraccer.blogspot.com
# campaign-archive2.com
# cnn.com
# netflix.com
# ronpaulinstitute.org
# occasion-to-be.com
# theguardian.com
# earthlink.com
# clasos.com.mx
# fundmycause.net
# lzomedia.com
# sharjah24.ae
# blacklistednews.com
# middleeasteye.net
# alarabiya.net
# cbsnews.com
# altnews.top
# telegraph.co.uk
# aa.com.tr
# russia-insider.com
# google.com
# therussophile.org
# theonlycolors.com
# mirror.co.uk
# irishtimes.com
# sinkers.org
# linkedin.com
# thefreethoughtproject.com
# worldaffairs.blog
# farsnews.com
# rightrelevance.com
# quiboat.com
# tumblr.com
# 1clickdaily.com
# truepatriot.net
# informationclearinghouse.info
# timesofnews.com
# noesis2017.com
# theamericanconservative.com
# podomatic.com
# dailymail.co.uk
# adf.ly
# ipsnews.net
# salon.com
# foxnews.com
# 1newsnet.com
# telesurtv.net
# lasvegasnvblog.com
# deazijnpisser.blogspot.com
# theintercept.com
# hnvnews.com
# getpocket.com
# nbcnews.com

# %%
import tweepy
import webbrowser
import time
import re
import requests

consumer_key = "7ZOCRSoDj7s98J1rIoKNEfaC8"
consumer_secret_key = "VpuPG2kLwF9b63ryupu3lLrcS01Wi3IDfsZLX7xNdv0HVwLvzC"
callback_uri ='oob'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret_key, callback_uri)
redirect_url = auth.get_authorization_url()

webbrowser.open(redirect_url)

user_pin_input = input("whats is the pin? ")

auth.get_access_token(user_pin_input)

api = tweepy.API(auth, wait_on_rate_limit=True)
# Out:
# newsteller.org
# washingtonpost.com
# feedburner.com
# mediasuarakyat.ga
# feedblitz.com
# rt.com
# theduran.com
# extrasensoryprecepts.blogspot.com
# sputniknews.com
# thetruthseeker.co.uk
# therealnews.com
# independent.co.uk
# veteranstoday.com
# thedailysheeple.com
# newsdeeply.com
# sott.net
# thesyriacampaign.org
# ems1.com
# seosem.es
# bbc.co.uk
# 21stcenturywire.com
# aljazeera.com
# yahoo.com
# gridirongarb.blogspot.com
# washingtonsblog.com
# 21stcenturywire.com
# sputniknews.com
# wrongkindofgreen.org
# rt.com
# steemit.com
# buzzfeed.com
# dailystar.com.lb
# independent.co.uk
# go.com
# mintpressnews.com
# mintpressnews.com
# nancysix.org
# spotify.com
# wikipedia.org
# blauerbote.com
# liveleak.com
# alligatorarmy.com
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-316e65504171> in <module>
#       9 callback_uri ='oob'
#      10
# ---> 11 auth = tweepy.OAuthHandler(consumer_key, consumer_secret_key, callback_uri)
#      12 redirect_url = auth.get_authorization_url()
#      13
#
# AttributeError: module 'tweepy' has no attribute 'OAuthHandler'
